# %%
import sys
sys.path.append('../')
import pyoption

from importlib import reload

# %%
reload(pyoption)
# Out:
# <module 'pyoption' from 'd:\\pyoption\\examples\\..\\pyoption\\__init__.py'>

# %%
c1 = pyoption.CallOption(exercise_price=100)
c2 = pyoption.CallOption(exercise_price=105)
c3 = pyoption.CallOption(exercise_price=110)

portpolio = c1 + c3 - c2 * 2

# %%
_ = c1.plot_pl(price_range=(90, 110))

# %%
_ = portpolio.plot_pl(price_range=(90, 130))
